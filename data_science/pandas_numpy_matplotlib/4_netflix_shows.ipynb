# %%
import pandas as pd
import string
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/netflix1.csv')
pd.options.display.min_rows = 12

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# 5         s9  TV Show     The Great British Baking Show  Andy Devonshire
# ...      ...      ...                               ...              ...
# 8784   s8796  TV Show                   Yu-Gi-Oh! Arc-V        Not Given
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#              country  date_added  release_year rating   duration  \
# 0      United States   9/25/2021          2020  PG-13     90 min
# 1             France   9/24/2021          2021  TV-MA   1 Season
# 2      United States   9/24/2021          2021  TV-MA   1 Season
# 3             Brazil   9/22/2021          2021  TV-PG     91 min
# 4      United States   9/24/2021          1993  TV-MA    125 min
# 5     United Kingdom   9/24/2021          2021  TV-14  9 Seasons
# ...              ...         ...           ...    ...        ...
# 8784           Japan    5/1/2018          2015  TV-Y7  2 Seasons
# 8785          Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786   United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787        Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788        Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789        Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# 5                          British TV Shows, Reality TV
# ...                                                 ...
# 8784                             Anime Series, Kids' TV
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %% [markdown]
# # Setting index corresponding to original dataset

# %%
df.show_id.str[0].str.isalpha().sum()
# Out:
# 8790

# %%
df.show_id = df.show_id.str[1:].astype(int)
df = df.set_index('show_id').sort_index()
df
# Out:
#             type                  title         director  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2        TV Show          Blood & Water        Not Given
# 3        TV Show              Ganglands  Julien Leclercq
# 4        TV Show  Jailbirds New Orleans        Not Given
# 5        TV Show           Kota Factory        Not Given
# 6        TV Show          Midnight Mass    Mike Flanagan
# ...          ...                    ...              ...
# 8802       Movie                Zinzana  Majid Al Ansari
# 8803       Movie                 Zodiac    David Fincher
# 8804     TV Show            Zombie Dumb        Not Given
# 8805       Movie             Zombieland  Ruben Fleischer
# 8806       Movie                   Zoom     Peter Hewitt
# 8807       Movie                 Zubaan      Mozez Singh
#
#                       country  date_added  release_year rating   duration  \
# show_id
# 1               United States   9/25/2021          2020  PG-13     90 min
# 2                South Africa   9/24/2021          2021  TV-MA  2 Seasons
# 3                      France   9/24/2021          2021  TV-MA   1 Season
# 4                    Pakistan   9/24/2021          2021  TV-MA   1 Season
# 5                       India   9/24/2021          2021  TV-MA  2 Seasons
# 6               United States   9/24/2021          2021  TV-MA   1 Season
# ...                       ...         ...           ...    ...        ...
# 8802     United Arab Emirates    3/9/2016          2015  TV-MA     96 min
# 8803            United States  11/20/2019          2007      R    158 min
# 8804                 Pakistan    7/1/2019          2018  TV-Y7  2 Seasons
# 8805            United States   11/1/2019          2009      R     88 min
# 8806            United States   1/11/2020          2006     PG     88 min
# 8807                    India    3/2/2019          2015  TV-14    111 min
#
#                                                  listed_in
# show_id
# 1                                            Documentaries
# 2          International TV Shows, TV Dramas, TV Mysteries
# 3        Crime TV Shows, International TV Shows, TV Act...
# 4                                   Docuseries, Reality TV
# 5        International TV Shows, Romantic TV Shows, TV ...
# 6                       TV Dramas, TV Horror, TV Mysteries
# ...                                                    ...
# 8802               Dramas, International Movies, Thrillers
# 8803                        Cult Movies, Dramas, Thrillers
# 8804                Kids' TV, Korean TV Shows, TV Comedies
# 8805                               Comedies, Horror Movies
# 8806                    Children & Family Movies, Comedies
# 8807        Dramas, International Movies, Music & Musicals
#
# [8790 rows x 9 columns]

# %% [markdown]
# # Fixing date format

# %%
df.date_added = pd.to_datetime(df['date_added'])
df.dtypes
# Out:
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %% [markdown]
# # Exploratory data analysis
# ## Searching for most popular directors

# %%
df.director.value_counts().nlargest(20)
# Out:
# Not Given                       2588
# Rajiv Chilaka                     20
# Raúl Campos, Jan Suter            18
# Alastair Fothergill               18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
# Cathy Garcia-Molina               13
# Martin Scorsese                   12
# Youssef Chahine                   12
# Jay Chapman                       12
# Steven Spielberg                  11
# Don Michael Paul                  10
# Mark Thornton, Todd Kauffman      10
# David Dhawan                       9
# Shannon Hartman                    8
# Fernando Ayllón                    8
# Yılmaz Erdoğan                     8
# Johnnie To                         8
# Troy Miller                        8
# Name: director, dtype: int64

# %%
df.insert(3, 'n_directed', 0)
df.n_directed = df.groupby('director')['director'].transform('count')

# %%
df.query('director == "Rajiv Chilaka"').count()[0]
# Out:
# 20

# %%
df.insert(4, 'director_known', 0)
df.director_known = (df.n_directed > 5) & (df.director != 'Not Given')
df.director_known.value_counts()
# Out:
# False    8313
# True      477
# Name: director_known, dtype: int64

# %%
df.query('director_known == True')
# Out:
#             type                                              title  \
# show_id
# 30         Movie                                           Paranoia
# 40       TV Show                                       Chhota Bheem
# 42         Movie                                               Jaws
# 52         Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 53         Movie  InuYasha the Movie 3: Swords of an Honorable R...
# 54         Movie    InuYasha the Movie 4: Fire on the Mystic Island
# ...          ...                                                ...
# 8683       Movie                                    Vizontele Tuuba
# 8697       Movie                                          War Horse
# 8732       Movie                                  While We're Young
# 8736       Movie                    Who's That Knocking at My Door?
# 8790       Movie                                You Changed My Life
# 8803       Movie                                             Zodiac
#
#                     director  n_directed  director_known        country  \
# show_id
# 30            Robert Luketic           6            True  United States
# 40             Rajiv Chilaka          20            True          India
# 42          Steven Spielberg          11            True  United States
# 52         Toshiya Shinohara           7            True          Japan
# 53         Toshiya Shinohara           7            True          Japan
# 54         Toshiya Shinohara           7            True          Japan
# ...                      ...         ...             ...            ...
# 8683          Yılmaz Erdoğan           8            True         Turkey
# 8697        Steven Spielberg          11            True  United States
# 8732           Noah Baumbach           6            True  United States
# 8736         Martin Scorsese          12            True  United States
# 8790     Cathy Garcia-Molina          13            True    Philippines
# 8803           David Fincher           6            True  United States
#
#         date_added  release_year rating   duration  \
# show_id
# 30      2021-09-19          2013  PG-13    106 min
# 40      2021-09-16          2021  TV-Y7  3 Seasons
# 42      2021-09-16          1975     PG    124 min
# 52      2021-09-15          2002  TV-14     99 min
# 53      2021-09-15          2003  TV-14     99 min
# 54      2021-09-15          2004  TV-PG     88 min
# ...            ...           ...    ...        ...
# 8683    2017-03-10          2004     NR    106 min
# 8697    2019-05-06          2011  PG-13    147 min
# 8732    2017-10-23          2015      R     97 min
# 8736    2019-07-01          1967      R     90 min
# 8790    2019-02-27          2009  TV-PG    116 min
# 8803    2019-11-20          2007      R    158 min
#
#                                                  listed_in
# show_id
# 30                                               Thrillers
# 40                                                Kids' TV
# 42              Action & Adventure, Classic Movies, Dramas
# 52       Action & Adventure, Anime Features, Internatio...
# 53       Action & Adventure, Anime Features, Internatio...
# 54       Action & Adventure, Anime Features, Internatio...
# ...                                                    ...
# 8683                Comedies, Dramas, International Movies
# 8697                                                Dramas
# 8732                  Comedies, Dramas, Independent Movies
# 8736            Classic Movies, Dramas, Independent Movies
# 8790                Comedies, Dramas, International Movies
# 8803                        Cult Movies, Dramas, Thrillers
#
# [477 rows x 11 columns]

# %% [markdown]
# ## Splitting duration into show and movie specific

# %%
df.duration.str.contains('Season').sum() + df.duration.str.contains('min').sum()
# Out:
# 8790

# %%
df.insert(10, 'show_n_seasons', 0)
df.insert(11, 'movie_dur_min', 0)

# %%
df.show_n_seasons = df.duration.where(df.duration.str.contains('Season'))
df.movie_dur_min = df.duration.where(df.duration.str.contains('min'))
df = df.drop('duration', axis='columns')

# %%
df.show_n_seasons = df.show_n_seasons.str.replace(r'[^0-9]', '').astype('float')
df.movie_dur_min = df.movie_dur_min.str.replace(r'[^0-9]', '').astype('float')
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_14772/2719161749.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.show_n_seasons = df.show_n_seasons.str.replace(r'[^0-9]', '').astype('float')
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_14772/2719161749.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.movie_dur_min = df.movie_dur_min.str.replace(r'[^0-9]', '').astype('float')
#             type                  title         director  n_directed  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson           1
# 2        TV Show          Blood & Water        Not Given        2588
# 3        TV Show              Ganglands  Julien Leclercq           3
# 4        TV Show  Jailbirds New Orleans        Not Given        2588
# 5        TV Show           Kota Factory        Not Given        2588
# 6        TV Show          Midnight Mass    Mike Flanagan           4
# ...          ...                    ...              ...         ...
# 8802       Movie                Zinzana  Majid Al Ansari           1
# 8803       Movie                 Zodiac    David Fincher           6
# 8804     TV Show            Zombie Dumb        Not Given        2588
# 8805       Movie             Zombieland  Ruben Fleischer           2
# 8806       Movie                   Zoom     Peter Hewitt           1
# 8807       Movie                 Zubaan      Mozez Singh           1
#
#          director_known               country date_added  release_year rating  \
# show_id
# 1                 False         United States 2021-09-25          2020  PG-13
# 2                 False          South Africa 2021-09-24          2021  TV-MA
# 3                 False                France 2021-09-24          2021  TV-MA
# 4                 False              Pakistan 2021-09-24          2021  TV-MA
# 5                 False                 India 2021-09-24          2021  TV-MA
# 6                 False         United States 2021-09-24          2021  TV-MA
# ...                 ...                   ...        ...           ...    ...
# 8802              False  United Arab Emirates 2016-03-09          2015  TV-MA
# 8803               True         United States 2019-11-20          2007      R
# 8804              False              Pakistan 2019-07-01          2018  TV-Y7
# 8805              False         United States 2019-11-01          2009      R
# 8806              False         United States 2020-01-11          2006     PG
# 8807              False                 India 2019-03-02          2015  TV-14
#
#          show_n_seasons  movie_dur_min  \
# show_id
# 1                   NaN           90.0
# 2                   2.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   2.0            NaN
# 6                   1.0            NaN
# ...                 ...            ...
# 8802                NaN           96.0
# 8803                NaN          158.0
# 8804                2.0            NaN
# 8805                NaN           88.0
# 8806                NaN           88.0
# 8807                NaN          111.0
#
#                                                  listed_in
# show_id
# 1                                            Documentaries
# 2          International TV Shows, TV Dramas, TV Mysteries
# 3        Crime TV Shows, International TV Shows, TV Act...
# 4                                   Docuseries, Reality TV
# 5        International TV Shows, Romantic TV Shows, TV ...
# 6                       TV Dramas, TV Horror, TV Mysteries
# ...                                                    ...
# 8802               Dramas, International Movies, Thrillers
# 8803                        Cult Movies, Dramas, Thrillers
# 8804                Kids' TV, Korean TV Shows, TV Comedies
# 8805                               Comedies, Horror Movies
# 8806                    Children & Family Movies, Comedies
# 8807        Dramas, International Movies, Music & Musicals
#
# [8790 rows x 12 columns]

# %% [markdown]
# ## Working on listed_in categories

# %%
df.listed_in.str.contains('Cult').sum()
# Out:
# 97

# %%
df.query('listed_in.str.contains("Cult") & director == "Not Given" & 2010 <= release_year <= 2015', engine='python')
# Out:
#             type                 title   director  n_directed  director_known  \
# show_id
# 5364     TV Show          The IT Crowd  Not Given        2588           False
# 6942     TV Show                 Haven  Not Given        2588           False
# 7258     TV Show  La Rosa de Guadalupe  Not Given        2588           False
#
#                 country date_added  release_year rating  show_n_seasons  \
# show_id
# 5364     United Kingdom 2017-08-01          2013  TV-MA             5.0
# 6942             Canada 2015-09-08          2015  TV-14             5.0
# 7258             Mexico 2019-01-15          2010  TV-PG             1.0
#
#          movie_dur_min                                          listed_in
# show_id
# 5364               NaN  British TV Shows, Classic & Cult TV, Internati...
# 6942               NaN         Classic & Cult TV, TV Horror, TV Mysteries
# 7258               NaN  Classic & Cult TV, Crime TV Shows, Internation...

# %%
df.query('type == "Movie" & 2 < n_directed < 10')
# Out:
#           type                                         title  \
# show_id
# 14       Movie              Confessions of an Invisible Girl
# 24       Movie  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 27       Movie                                Minsara Kanavu
# 28       Movie                                     Grown Ups
# 30       Movie                                      Paranoia
# 49       Movie                                  Training Day
# ...        ...                                           ...
# 8769     Movie                             Y Tu Mamá También
# 8771     Movie                                       Yaadein
# 8783     Movie                                   Yoga Hosers
# 8791     Movie                 You Don't Mess with the Zohan
# 8794     Movie                          Yours, Mine and Ours
# 8803     Movie                                        Zodiac
#
#                         director  n_directed  director_known        country  \
# show_id
# 14                 Bruno Garotti           4           False         Brazil
# 24       Alex Woo, Stanley Moore           3           False  United States
# 27                   Rajiv Menon           3           False          India
# 28                  Dennis Dugan           4           False  United States
# 30                Robert Luketic           6            True  United States
# 49                 Antoine Fuqua           4           False  United States
# ...                          ...         ...             ...            ...
# 8769              Alfonso Cuarón           3           False         Mexico
# 8771                Subhash Ghai           4           False          India
# 8783                 Kevin Smith           5           False  United States
# 8791                Dennis Dugan           4           False  United States
# 8794                Raja Gosnell           4           False  United States
# 8803               David Fincher           6            True  United States
#
#         date_added  release_year rating  show_n_seasons  movie_dur_min  \
# show_id
# 14      2021-09-22          2021  TV-PG             NaN           91.0
# 24      2021-09-21          2021   TV-Y             NaN           61.0
# 27      2021-09-21          1997  TV-PG             NaN          147.0
# 28      2021-09-20          2010  PG-13             NaN          103.0
# 30      2021-09-19          2013  PG-13             NaN          106.0
# 49      2021-09-16          2001      R             NaN          122.0
# ...            ...           ...    ...             ...            ...
# 8769    2017-06-01          2001      R             NaN          106.0
# 8771    2018-03-01          2001  TV-14             NaN          171.0
# 8783    2016-12-02          2016  PG-13             NaN           88.0
# 8791    2019-09-01          2008     UR             NaN          113.0
# 8794    2019-11-20          2005     PG             NaN           88.0
# 8803    2019-11-20          2007      R             NaN          158.0
#
#                                                 listed_in
# show_id
# 14                     Children & Family Movies, Comedies
# 24                               Children & Family Movies
# 27       Comedies, International Movies, Music & Musicals
# 28                                               Comedies
# 30                                              Thrillers
# 49                                      Dramas, Thrillers
# ...                                                   ...
# 8769     Dramas, Independent Movies, International Movies
# 8771        Dramas, International Movies, Romantic Movies
# 8783          Comedies, Horror Movies, Independent Movies
# 8791                         Action & Adventure, Comedies
# 8794                   Children & Family Movies, Comedies
# 8803                       Cult Movies, Dramas, Thrillers
#
# [1303 rows x 12 columns]

# %%
df_check = df.query('(country == "India" | country == "Pakistan") & date_added > "2019-10-10"')
df_check.query('date_added <= "2019-10-10"')
# Out:
# Empty DataFrame
# Columns: [type, title, director, n_directed, director_known, country, date_added, release_year, rating, show_n_seasons, movie_dur_min, listed_in]
# Index: []

# %%
df['listed_in'].str.split(', ', expand=True).stack().value_counts()
# Out:
# International Movies            2752
# Dramas                          2426
# Comedies                        1674
# International TV Shows          1349
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        762
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# Thrillers                        577
# TV Comedies                      573
# Crime TV Shows                   469
# Kids' TV                         448
# Docuseries                       394
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 252
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     174
# Spanish-Language TV Shows        173
# TV Action & Adventure            167
# Korean TV Shows                  151
# Classic Movies                   116
# LGBTQ Movies                     102
# TV Mysteries                      98
# Science & Nature TV               92
# TV Sci-Fi & Fantasy               83
# TV Horror                         75
# Anime Features                    71
# Cult Movies                       71
# Teen TV Shows                     69
# Faith & Spirituality              65
# TV Thrillers                      57
# Stand-Up Comedy & Talk Shows      56
# Movies                            53
# Classic & Cult TV                 26
# TV Shows                          16
# dtype: int64

# %%
df.listed_in = df.listed_in.str.replace('TV','')
df.listed_in = df.listed_in.str.replace('Shows','')
df.listed_in = df.listed_in.str.replace('Movies','')
df.listed_in = df.listed_in.str.replace('','')
df.listed_in = df.listed_in.replace(r'\s+', ' ', regex=True)
df
# Out:
#             type                  title         director  n_directed  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson           1
# 2        TV Show          Blood & Water        Not Given        2588
# 3        TV Show              Ganglands  Julien Leclercq           3
# 4        TV Show  Jailbirds New Orleans        Not Given        2588
# 5        TV Show           Kota Factory        Not Given        2588
# 6        TV Show          Midnight Mass    Mike Flanagan           4
# ...          ...                    ...              ...         ...
# 8802       Movie                Zinzana  Majid Al Ansari           1
# 8803       Movie                 Zodiac    David Fincher           6
# 8804     TV Show            Zombie Dumb        Not Given        2588
# 8805       Movie             Zombieland  Ruben Fleischer           2
# 8806       Movie                   Zoom     Peter Hewitt           1
# 8807       Movie                 Zubaan      Mozez Singh           1
#
#          director_known               country date_added  release_year rating  \
# show_id
# 1                 False         United States 2021-09-25          2020  PG-13
# 2                 False          South Africa 2021-09-24          2021  TV-MA
# 3                 False                France 2021-09-24          2021  TV-MA
# 4                 False              Pakistan 2021-09-24          2021  TV-MA
# 5                 False                 India 2021-09-24          2021  TV-MA
# 6                 False         United States 2021-09-24          2021  TV-MA
# ...                 ...                   ...        ...           ...    ...
# 8802              False  United Arab Emirates 2016-03-09          2015  TV-MA
# 8803               True         United States 2019-11-20          2007      R
# 8804              False              Pakistan 2019-07-01          2018  TV-Y7
# 8805              False         United States 2019-11-01          2009      R
# 8806              False         United States 2020-01-11          2006     PG
# 8807              False                 India 2019-03-02          2015  TV-14
#
#          show_n_seasons  movie_dur_min  \
# show_id
# 1                   NaN           90.0
# 2                   2.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   2.0            NaN
# 6                   1.0            NaN
# ...                 ...            ...
# 8802                NaN           96.0
# 8803                NaN          158.0
# 8804                2.0            NaN
# 8805                NaN           88.0
# 8806                NaN           88.0
# 8807                NaN          111.0
#
#                                           listed_in
# show_id
# 1                                     Documentaries
# 2                 International , Dramas, Mysteries
# 3        Crime , International , Action & Adventure
# 4                              Docuseries, Reality
# 5               International , Romantic , Comedies
# 6                         Dramas, Horror, Mysteries
# ...                                             ...
# 8802              Dramas, International , Thrillers
# 8803                       Cult , Dramas, Thrillers
# 8804                      Kids' , Korean , Comedies
# 8805                              Comedies, Horror
# 8806                   Children & Family , Comedies
# 8807       Dramas, International , Music & Musicals
#
# [8790 rows x 12 columns]

# %%
df.listed_in = df.listed_in.str.replace('Dramas','Drama')
df.listed_in = df.listed_in.str.replace('Comedies','Comedy')
df.listed_in = df.listed_in.str.replace('Mysteries','Mystery')
df.listed_in = df.listed_in.str.replace('Docuseries','Documentaries')
df.listed_in = df.listed_in.str.replace('Documentaries','Documentary')
df.listed_in = df.listed_in.str.replace('Thrillers','Thriller')
df.listed_in = df.listed_in.str.replace('Series','')
df.listed_in = df.listed_in.str.replace(' &',',')
df.listed_in = df.listed_in.str.replace("' ",'')
df.listed_in = df.listed_in.str.replace(',','')
df.listed_in = df.listed_in.str.replace(' ',',')
df.listed_in = df.listed_in.str.replace(',,',',')
# df.listed_in.unique()

# %%
df.query('listed_in.str[0] == ","').listed_in.str[1:]
df
# Out:
#             type                  title         director  n_directed  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson           1
# 2        TV Show          Blood & Water        Not Given        2588
# 3        TV Show              Ganglands  Julien Leclercq           3
# 4        TV Show  Jailbirds New Orleans        Not Given        2588
# 5        TV Show           Kota Factory        Not Given        2588
# 6        TV Show          Midnight Mass    Mike Flanagan           4
# ...          ...                    ...              ...         ...
# 8802       Movie                Zinzana  Majid Al Ansari           1
# 8803       Movie                 Zodiac    David Fincher           6
# 8804     TV Show            Zombie Dumb        Not Given        2588
# 8805       Movie             Zombieland  Ruben Fleischer           2
# 8806       Movie                   Zoom     Peter Hewitt           1
# 8807       Movie                 Zubaan      Mozez Singh           1
#
#          director_known               country date_added  release_year rating  \
# show_id
# 1                 False         United States 2021-09-25          2020  PG-13
# 2                 False          South Africa 2021-09-24          2021  TV-MA
# 3                 False                France 2021-09-24          2021  TV-MA
# 4                 False              Pakistan 2021-09-24          2021  TV-MA
# 5                 False                 India 2021-09-24          2021  TV-MA
# 6                 False         United States 2021-09-24          2021  TV-MA
# ...                 ...                   ...        ...           ...    ...
# 8802              False  United Arab Emirates 2016-03-09          2015  TV-MA
# 8803               True         United States 2019-11-20          2007      R
# 8804              False              Pakistan 2019-07-01          2018  TV-Y7
# 8805              False         United States 2019-11-01          2009      R
# 8806              False         United States 2020-01-11          2006     PG
# 8807              False                 India 2019-03-02          2015  TV-14
#
#          show_n_seasons  movie_dur_min                             listed_in
# show_id
# 1                   NaN           90.0                           Documentary
# 2                   2.0            NaN           International,Drama,Mystery
# 3                   1.0            NaN  Crime,International,Action,Adventure
# 4                   1.0            NaN                  Documentary,Reality,
# 5                   2.0            NaN         International,Romantic,Comedy
# 6                   1.0            NaN                 ,Drama,Horror,Mystery
# ...                 ...            ...                                   ...
# 8802                NaN           96.0          Drama,International,Thriller
# 8803                NaN          158.0                   Cult,Drama,Thriller
# 8804                2.0            NaN                    Kids,Korean,Comedy
# 8805                NaN           88.0                        Comedy,Horror,
# 8806                NaN           88.0                Children,Family,Comedy
# 8807                NaN          111.0    Drama,International,Music,Musicals
#
# [8790 rows x 12 columns]

# %%
df.listed_in = df.listed_in.apply(lambda x : x[1:] if x.startswith(",") else x)
df.listed_in = df.listed_in.apply(lambda x : x[:-1] if x.endswith(',') else x)
df.listed_in.unique()
# Out:
# array(['Documentary', 'International,Drama,Mystery',
#        'Crime,International,Action,Adventure', 'Documentary,Reality',
#        'International,Romantic,Comedy', 'Drama,Horror,Mystery',
#        'Children,Family', 'Drama,Independent,International',
#        'British,Reality', 'Comedy,Drama',
#        'Crime,Documentary,International', 'Drama,International',
#        'Children,Family,Comedy', 'British,Crime,Documentary',
#        'Documentary,International', 'Crime,Spanish-Language,Drama',
#        'Thriller', 'International,Spanish-Language,Action,Adventure',
#        'International,Action,Adventure,Drama', 'Comedy,International',
#        'Comedy,International,Romantic',
#        'Documentary,International,Reality',
#        'Comedy,International,Music,Musicals', 'Comedy',
#        'Horror,Sci-Fi,Fantasy', 'British,International,Comedy',
#        'International,Drama,Thriller', 'Kids',
#        'Drama,International,Thriller',
#        'Action,Adventure,Drama,International', 'Kids,Comedy',
#        'Action,Adventure,Drama', 'Kids,Sci-Fi,Fantasy',
#        'Action,Adventure,Classic,Drama', 'Drama,Horror,Thriller',
#        'Action,Adventure,Horror,Thriller', 'Action,Adventure',
#        'Drama,Thriller', 'International,Drama',
#        'International,Drama,Sci-Fi,Fantasy',
#        'Action,Adventure,Anime,Features,International', 'Reality',
#        'Documentary,International,Sports',
#        'International,Reality,Romantic',
#        'British,Documentary,International', 'Anime,International',
#        'Comedy,Drama,International', 'Crime,Comedy,Drama',
#        'Action,Adventure,Comedy,Drama', 'Anime,Kids',
#        'International,Thriller', 'Kids,Korean', 'Documentary,Sports',
#        'Sci-Fi,Fantasy,Thriller', 'Drama,International,Romantic',
#        'Documentary,Music,Musicals', 'Kids,Comedy,Sci-Fi,Fantasy',
#        'British,Kids', 'Documentary,Science,Nature',
#        'Children,Family,Drama', 'Kids,Drama,Teen',
#        'Crime,International,Spanish-Language',
#        'Documentary,International,Spanish-Language', 'Drama',
#        'Comedy,Romantic', 'Drama,Romantic', 'Comedy,Drama,Independent',
#        'Crime,Action,Adventure,Comedy', 'Children,Family,Music,Musicals',
#        'Action,Adventure,Classic,Cult',
#        'International,Action,Adventure,Comedy',
#        'Action,Adventure,Sci-Fi,Fantasy', 'Action,Adventure,Comedy',
#        'Classic,Comedy,Drama', 'Comedy,Cult',
#        'Comedy,Cult,Music,Musicals', 'Comedy,Music,Musicals', '',
#        'Action,Adventure,International', 'Anime,International,Teen',
#        'Action,Adventure,Children,Family,Cult', 'Comedy,Drama,Romantic',
#        'Comedy,Cult,Sci-Fi,Fantasy', 'Classic,Drama',
#        'Action,Adventure,Children,Family,Comedy',
#        'Drama,Faith,Spirituality', 'Documentary,LGBTQ',
#        'Action,Adventure,Classic', 'International,Comedy',
#        'Drama,Independent', 'Action,Adventure,Comedy,International',
#        'International,Spanish-Language,Drama',
#        'Crime,International,Drama',
#        'Action,Adventure,Horror,International',
#        'Comedy,International,Sci-Fi,Fantasy',
#        'Action,Adventure,International,Music,Musicals',
#        'Drama,International,Music,Musicals', 'Horror,International',
#        'Reality,Teen', 'Crime,Drama,Mystery', 'International,Reality',
#        'International,Comedy,Drama', 'Drama,Independent,Romantic',
#        'Horror', 'Documentary,LGBTQ,Sports',
#        'Horror,International,Thriller', 'Action,Adventure,Anime,Features',
#        'Drama,Mystery,Sci-Fi,Fantasy',
#        'International,Spanish-Language,Comedy',
#        'Children,Family,Comedy,Music,Musicals', 'Comedy,Independent',
#        'Anime,International,Romantic', 'Classic,Drama,Independent',
#        'International,Romantic,Spanish-Language',
#        'International,Drama,Teen', 'Stand-Up,Comedy',
#        'Action,Adventure,Anime,Features,Children,Family',
#        'International,Romantic,Drama', 'International,Music,Musicals',
#        'Action,Adventure,Drama,Mystery',
#        'Horror,Independent,International', 'Comedy,Cult,International',
#        'Classic,Drama,International', 'Crime,Documentary',
#        'Children,Family,Comedy,Sci-Fi,Fantasy',
#        'Anime,International,Thriller',
#        'Action,Adventure,Horror,Sci-Fi,Fantasy', 'Classic,Comedy,Cult',
#        'Drama,Teen', 'Action,Adventure,Sci-Fi,Fantasy,Thriller',
#        'Children,Family,Comedy,Drama', 'Drama,Sports',
#        'Action,Adventure,Drama,Sci-Fi,Fantasy',
#        'Action,Adventure,Comedy,Cult', 'Drama,Independent,Thriller',
#        'Drama,Sci-Fi,Fantasy', 'Action,Adventure,International,Thriller',
#        'British,International,Reality', 'Action,Adventure,Drama,Teen',
#        'Anime', 'Crime,Action,Adventure,Sci-Fi,Fantasy',
#        'Crime,International,Comedy', 'Stand-Up,Comedy,Talk,Comedy',
#        'Classic,Cult,Action,Adventure,Drama', 'Children,Family,Sports',
#        'Anime,Stand-Up,Comedy,Talk',
#        'Anime,Features,Children,Family,International',
#        'Classic,Cult,Crime,International', 'Crime,International,Romantic',
#        'Horror,LGBTQ', 'Action,Adventure,Drama,Romantic',
#        'Documentary,International,Music,Musicals', 'Comedy,Drama,Teen',
#        'Children,Family,Comedy,Sports',
#        'Children,Family,Drama,International',
#        'Comedy,Documentary,International', 'Romantic,Drama',
#        'Anime,Horror,Thriller', 'International,Romantic',
#        'Kids,Korean,Comedy', 'British,Crime,International',
#        'Crime,Horror,Mystery', 'Documentary,International,Science,Nature',
#        'British,International,Drama',
#        'Kids,Action,Adventure,Sci-Fi,Fantasy',
#        'International,Romantic,Thriller',
#        'Action,Adventure,Cult,International',
#        'Action,Adventure,Comedy,Sci-Fi,Fantasy',
#        'International,Kids,Mystery', 'Action,Adventure,Thriller',
#        'Drama,Faith,Spirituality,International',
#        'Action,Adventure,Classic,Comedy',
#        'Action,Adventure,Comedy,Sports',
#        'Action,Adventure,Children,Family,Classic',
#        'Action,Adventure,Children,Family,Drama', 'Horror,Thriller',
#        'Action,Adventure,Romantic', 'Drama,Romantic,Sci-Fi,Fantasy',
#        'Drama,Music,Musicals,Romantic', 'Anime,Crime,International',
#        'Reality,Romantic', 'International,Music,Musicals,Romantic',
#        'Reality,Action,Adventure,Mystery', 'Crime,Drama',
#        'International,Reality,Spanish-Language', 'Crime,Drama,Thriller',
#        'British,Documentary', 'International,Korean,Comedy',
#        'Action,Adventure,Anime,Features,Classic',
#        'Action,Adventure,Drama,Horror', 'Crime,International,Thriller',
#        'Anime,Crime,Horror', 'Anime,Features,Documentary',
#        'Comedy,Horror',
#        'International,Spanish-Language,Stand-Up,Comedy,Talk',
#        'Children,Family,Documentary,International',
#        'Romantic,Comedy,Drama', 'Drama,Faith,Spirituality,Romantic',
#        'Drama,Independent,LGBTQ', 'Comedy,Independent,LGBTQ',
#        'Action,Adventure,Cult,Sci-Fi,Fantasy', 'Cult,Horror',
#        'Action,Adventure,Drama,Sports', 'Anime,Romantic,Teen',
#        'Drama,International,LGBTQ', 'Drama,Romantic,Thriller',
#        'Children,Family,Drama,Faith,Spirituality',
#        'Drama,International,Sports', 'Action,Adventure,Horror',
#        'Documentary,International,LGBTQ',
#        'Drama,Independent,Sci-Fi,Fantasy',
#        'Comedy,Independent,International', 'Reality,Horror,Thriller',
#        'International,Horror,Sci-Fi,Fantasy',
#        'Independent,International,Thriller', 'Independent,Thriller',
#        'Documentary,Drama', 'Action,Adventure,Sports',
#        'Drama,International,Sci-Fi,Fantasy',
#        'Comedy,Independent,Romantic', 'Horror,Romantic,Sci-Fi,Fantasy',
#        'International,Stand-Up,Comedy,Talk',
#        'Action,Adventure,Anime,Features,Horror',
#        'Cult,Drama,Music,Musicals', 'Crime,International,Korean',
#        'Horror,Mystery,Thriller', 'Comedy,Horror,International',
#        'Crime,Documentary,Mystery', 'Comedy,International,Sports',
#        'Classic,Music,Musicals', 'Reality,Comedy,Horror',
#        'Children,Family,Faith,Spirituality,Music,Musicals',
#        'International,Korean,Stand-Up,Comedy,Talk',
#        'Drama,Music,Musicals',
#        'Documentary,Science,Nature,Action,Adventure',
#        'British,Kids,Drama', 'International,Korean,Romantic',
#        'Horror,Independent', 'Anime,Kids,Action,Adventure',
#        'Comedy,Drama,Music,Musicals', 'Horror,Teen',
#        'Comedy,LGBTQ,Thriller', 'Documentary,Reality,Science,Nature',
#        'Crime,Spanish-Language,Action,Adventure', 'Romantic,Teen',
#        'Comedy,Teen', 'Romantic,Drama,Teen',
#        'Children,Family,Sci-Fi,Fantasy',
#        'Romantic,Action,Adventure,Drama', 'Comedy,International,LGBTQ',
#        'Kids,Thriller', 'British,Romantic,Drama',
#        'Anime,International,Spanish-Language', 'Documentary,Comedy',
#        'Comedy,Romantic,Sports', 'Children,Family,Drama,Sports',
#        'Action,Adventure,Drama,Independent', 'Spanish-Language,Drama',
#        'Drama,LGBTQ', 'Horror,Mystery,Sci-Fi,Fantasy',
#        'Action,Adventure,Drama,Faith,Spirituality',
#        'International,Mystery,Thriller',
#        'British,Classic,Cult,International',
#        'Action,Adventure,Comedy,Independent', 'Music,Musicals',
#        'British,Kids,Comedy', 'Documentary,Spanish-Language',
#        'Drama,Independent,Sports', 'Drama,Mystery,Thriller',
#        'Comedy,LGBTQ,Music,Musicals',
#        'International,Action,Adventure,Mystery', 'Kids,Comedy,Teen',
#        'International,Drama,Horror', 'Comedy,International,Thriller',
#        'Classic,Cult,Action,Adventure,Sci-Fi,Fantasy',
#        'International,Horror,Mystery', 'Children,Family,Documentary',
#        'Music,Musicals,Romantic', 'Romantic',
#        'Children,Family,Classic,Comedy', 'Drama,LGBTQ,Romantic',
#        'Children,Family,Comedy,Romantic', 'Comedy,Sports',
#        'International', 'International,Romantic,Mystery',
#        'Stand-Up,Comedy,Talk', 'Action,Adventure,International,Romantic',
#        'Reality,Comedy', 'Cult,Drama,International', 'Kids,Drama',
#        'Crime,International,Mystery',
#        'Action,Adventure,Sci-Fi,Fantasy,Sports',
#        'Drama,Sci-Fi,Fantasy,Thriller', 'Romantic,Drama,Sci-Fi,Fantasy',
#        'Documentary,Sci-Fi,Fantasy', 'Anime,Features,International',
#        'British,Classic,Cult,Kids', 'British,Reality,Romantic',
#        'Documentary,Faith,Spirituality,International',
#        'Kids,Reality,Drama', 'LGBTQ,Thriller',
#        'Action,Adventure,Mystery,Sci-Fi,Fantasy',
#        'Reality,Science,Nature', 'Kids,Action,Adventure,Comedy',
#        'International,Romantic,Action,Adventure',
#        'Children,Family,Drama,Independent',
#        'Comedy,Music,Musicals,Romantic', 'International,Korean,Reality',
#        'Classic,Cult,Drama,Sci-Fi,Fantasy',
#        'Anime,Features,Children,Family',
#        'Action,Adventure,International,Sci-Fi,Fantasy',
#        'Crime,Action,Adventure,Drama',
#        'Classic,Cult,Action,Adventure,Horror',
#        'International,Korean,Drama',
#        'International,Action,Adventure,Horror',
#        'Action,Adventure,Comedy,Romantic',
#        'International,Korean,Action,Adventure',
#        'Classic,Cult,Kids,Action,Adventure', 'Anime,International,Horror',
#        'International,Korean,Horror',
#        'Children,Family,Comedy,International',
#        'International,Sci-Fi,Fantasy',
#        'International,Sci-Fi,Fantasy,Thriller',
#        'Children,Family,Drama,Romantic', 'Anime,Romantic',
#        'Comedy,Drama,LGBTQ', 'British,International,Action,Adventure',
#        'Documentary,Science,Nature,Comedy',
#        'International,Stand-Up,Comedy,Talk,Comedy',
#        'Children,Family,Drama,Music,Musicals',
#        'Action,Adventure,Independent,International',
#        'Action,Adventure,Children,Family,Sci-Fi,Fantasy',
#        'Horror,Independent,Sci-Fi,Fantasy', 'Drama,Sci-Fi,Fantasy,Teen',
#        'Anime,Features,International,Sci-Fi,Fantasy',
#        'Drama,Independent,Music,Musicals', 'Kids,Comedy,Drama',
#        'Children,Family,Documentary,Sports',
#        'Independent,Sci-Fi,Fantasy,Thriller',
#        'Anime,Features,Music,Musicals,Sci-Fi,Fantasy',
#        'Comedy,Drama,Sci-Fi,Fantasy', 'Crime,Action,Adventure',
#        'Comedy,Faith,Spirituality,Romantic', 'Kids,Action,Adventure',
#        'Action,Adventure,Independent', 'International,Reality,Comedy',
#        'Documentary,Reality,Teen', 'Crime,International,Reality',
#        'Anime,Teen', 'Crime,Romantic,Drama', 'Anime,Features,Romantic',
#        'Horror,Sci-Fi,Fantasy,Thriller',
#        'International,Comedy,Sci-Fi,Fantasy',
#        'Anime,Features,Music,Musicals',
#        'Anime,Features,International,Romantic',
#        'International,Romantic,Teen', 'Documentary,Stand-Up,Comedy,Talk',
#        'Horror,Independent,Thriller', 'Action,Adventure,Comedy,Horror',
#        'Documentary,Stand-Up,Comedy', 'Kids,Spanish-Language',
#        'British,Kids,Thriller', 'Kids,Action,Adventure,Drama',
#        'Anime,Crime', 'Comedy,Drama,Horror',
#        'Children,Family,Comedy,LGBTQ',
#        'International,Action,Adventure,Sci-Fi,Fantasy',
#        'Horror,International,Romantic',
#        'Crime,Documentary,Science,Nature',
#        'International,Music,Musicals,Thriller',
#        'Kids,Spanish-Language,Teen', 'Comedy,Horror,Independent',
#        'Action,Adventure,International,Sports',
#        'Action,Adventure,Independent,Sci-Fi,Fantasy',
#        'Horror,LGBTQ,Music,Musicals', 'Comedy,Music,Musicals,Sports',
#        'Horror,Mystery,Teen', 'Romantic,Comedy',
#        'Kids,Reality,Science,Nature',
#        'International,Romantic,Sci-Fi,Fantasy', 'Comedy,Horror,Thriller',
#        'International,Spanish-Language,Horror',
#        'Crime,Action,Adventure,Thriller',
#        'Music,Musicals,Stand-Up,Comedy', 'British,Comedy',
#        'Comedy,Sci-Fi,Fantasy,Teen', 'Comedy,Sci-Fi,Fantasy',
#        'Romantic,Spanish-Language,Comedy',
#        'Crime,International,Sci-Fi,Fantasy',
#        'British,International,Romantic', 'Crime,Kids',
#        'Horror,International,Sci-Fi,Fantasy', 'Comedy,Mystery',
#        'Cult,Horror,Independent', 'British,Documentary,Comedy',
#        'Comedy,Documentary', 'Reality,Science,Nature,Action,Adventure',
#        'Comedy,Drama,Mystery', 'Crime,Comedy,Teen',
#        'Documentary,Kids,Science,Nature', 'Reality,Spanish-Language',
#        'Action,Adventure,Anime,Features,Sci-Fi,Fantasy',
#        'Crime,Kids,Comedy', 'Drama,Faith,Spirituality,Independent',
#        'Documentary,Faith,Spirituality',
#        'British,International,Stand-Up,Comedy,Talk',
#        'Comedy,Drama,Faith,Spirituality', 'Classic,Cult,Comedy',
#        'Drama,Romantic,Sports',
#        'Stand-Up,Comedy,Talk,Mystery,Sci-Fi,Fantasy',
#        'Comedy,Independent,Music,Musicals', 'Comedy,Cult,Independent',
#        'Documentary,Drama,International', 'British,Horror,Thriller',
#        'British,Documentary,Science,Nature',
#        'Children,Family,Comedy,Cult', 'Sports', 'Sci-Fi,Fantasy',
#        'Comedy,LGBTQ', 'Comedy,Independent,Thriller',
#        'Classic,Cult,Drama',
#        'Action,Adventure,Children,Family,Independent',
#        'Action,Adventure,Documentary,International',
#        'Children,Family,Independent', 'Comedy,Cult,Drama',
#        'International,Horror,Thriller', 'Classic,Thriller',
#        'Crime,Drama,Horror', 'British,Documentary,Reality',
#        'Documentary,LGBTQ,Music,Musicals', 'Classic,Drama,Romantic',
#        'Crime,Romantic,Spanish-Language', 'Classic,Cult,Horror',
#        'Anime,Crime,Thriller', 'Children,Family,Classic',
#        'Classic,Comedy,International', 'Action,Adventure,Cult,Drama',
#        'Documentary,Faith,Spirituality,Music,Musicals',
#        'British,Classic,Cult,Comedy', 'International,Sports',
#        'Classic,Cult,Kids,Spanish-Language',
#        'Romantic,Spanish-Language,Drama',
#        'Children,Family,Comedy,Faith,Spirituality', 'British,Crime,Drama',
#        'Classic,Drama,Music,Musicals', 'Cult,Horror,Thriller',
#        'Action,Adventure,Classic,Sci-Fi,Fantasy',
#        'Classic,Comedy,Music,Musicals', 'Independent',
#        'Documentary,Horror', 'Classic,Cult,Horror,Mystery',
#        'Comedy,Faith,Spirituality,International',
#        'Drama,Horror,Sci-Fi,Fantasy', 'British,Drama,Sci-Fi,Fantasy',
#        'Comedy,Cult,Horror', 'Comedy,Cult,Sports', 'Classic,Documentary',
#        'Action,Adventure,Faith,Spirituality,Sci-Fi,Fantasy',
#        'Action,Adventure,Children,Family',
#        'International,Reality,Action,Adventure',
#        'Documentary,Science,Nature,Drama', 'Anime,Features',
#        'Action,Adventure,Horror,Independent',
#        'Action,Adventure,Classic,International',
#        'Cult,Independent,Thriller', 'Crime,Comedy',
#        'Classic,Cult,Documentary', 'Classic,Cult,Kids,Comedy',
#        'Classic,Drama,LGBTQ', 'Classic,Drama,Sports',
#        'Action,Adventure,Cult', 'Action,Adventure,Comedy,Music,Musicals',
#        'Classic,Horror,Thriller', 'Classic,Comedy,Independent',
#        'Children,Family,Classic,Drama', 'Drama,Faith,Spirituality,Sports',
#        'Classic,Comedy,Romantic', 'Drama,Horror,Music,Musicals',
#        'Classic,Independent,Thriller',
#        'Children,Family,Faith,Spirituality', 'Classic,Comedy,Sports',
#        'Comedy,Drama,Sports', 'Action,Adventure,Romantic,Sci-Fi,Fantasy',
#        'Classic,Cult,Sci-Fi,Fantasy', 'Comedy,Cult,LGBTQ',
#        'Comedy,Horror,Sci-Fi,Fantasy', 'Classic,Cult,Crime,Drama',
#        'Action,Adventure,Documentary,Sports',
#        'International,LGBTQ,Romantic', 'Cult,Drama,Thriller'],
#       dtype=object)

# %%
df
# Out:
#             type                  title         director  n_directed  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson           1
# 2        TV Show          Blood & Water        Not Given        2588
# 3        TV Show              Ganglands  Julien Leclercq           3
# 4        TV Show  Jailbirds New Orleans        Not Given        2588
# 5        TV Show           Kota Factory        Not Given        2588
# 6        TV Show          Midnight Mass    Mike Flanagan           4
# ...          ...                    ...              ...         ...
# 8802       Movie                Zinzana  Majid Al Ansari           1
# 8803       Movie                 Zodiac    David Fincher           6
# 8804     TV Show            Zombie Dumb        Not Given        2588
# 8805       Movie             Zombieland  Ruben Fleischer           2
# 8806       Movie                   Zoom     Peter Hewitt           1
# 8807       Movie                 Zubaan      Mozez Singh           1
#
#          director_known               country date_added  release_year rating  \
# show_id
# 1                 False         United States 2021-09-25          2020  PG-13
# 2                 False          South Africa 2021-09-24          2021  TV-MA
# 3                 False                France 2021-09-24          2021  TV-MA
# 4                 False              Pakistan 2021-09-24          2021  TV-MA
# 5                 False                 India 2021-09-24          2021  TV-MA
# 6                 False         United States 2021-09-24          2021  TV-MA
# ...                 ...                   ...        ...           ...    ...
# 8802              False  United Arab Emirates 2016-03-09          2015  TV-MA
# 8803               True         United States 2019-11-20          2007      R
# 8804              False              Pakistan 2019-07-01          2018  TV-Y7
# 8805              False         United States 2019-11-01          2009      R
# 8806              False         United States 2020-01-11          2006     PG
# 8807              False                 India 2019-03-02          2015  TV-14
#
#          show_n_seasons  movie_dur_min                             listed_in
# show_id
# 1                   NaN           90.0                           Documentary
# 2                   2.0            NaN           International,Drama,Mystery
# 3                   1.0            NaN  Crime,International,Action,Adventure
# 4                   1.0            NaN                   Documentary,Reality
# 5                   2.0            NaN         International,Romantic,Comedy
# 6                   1.0            NaN                  Drama,Horror,Mystery
# ...                 ...            ...                                   ...
# 8802                NaN           96.0          Drama,International,Thriller
# 8803                NaN          158.0                   Cult,Drama,Thriller
# 8804                2.0            NaN                    Kids,Korean,Comedy
# 8805                NaN           88.0                         Comedy,Horror
# 8806                NaN           88.0                Children,Family,Comedy
# 8807                NaN          111.0    Drama,International,Music,Musicals
#
# [8790 rows x 12 columns]

# %% [markdown]
# ## Displaying interesting data

# %%
(df.query('director != "Not Given" & n_directed > 10')
 .groupby(by=df['director'])
 .n_directed
 .count()
 .sort_values(ascending=False)
 .plot(x='director', y='n_directed', kind='bar', ylabel='n_directed', title='Most movies/shows by director', yticks=range(0, 22, 2), figsize=(10,5))
)
# Out:
# <AxesSubplot:title={'center':'Most movies/shows by director'}, xlabel='director', ylabel='n_directed'>

# %%
(df.groupby(by=['country'])
 .count()
 .query('n_directed>=50')
 .n_directed
 .sort_values(ascending=False)
 .plot(xlabel='country', ylabel='n_directed', title='most movies/shows by country', kind='bar', ylim=(0, 1000), figsize=(10,5))
)
# Out:
# <AxesSubplot:title={'center':'most movies/shows by country'}, xlabel='country', ylabel='n_directed'>

# %%
(df.query('type == "Movie"')
 .groupby(by=['release_year'])
 .mean()
 .movie_dur_min
 .plot(kind='line', ylabel='mean duration, min', title='mean movie dur vs release year', figsize=(10,5))
)
# Out:
# <AxesSubplot:title={'center':'mean movie dur vs release year'}, xlabel='release_year', ylabel='mean duration, min'>

# %%
df.query('type == "Movie"').movie_dur_min.describe()
# Out:
# count    6126.000000
# mean       99.584884
# std        28.283225
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: movie_dur_min, dtype: float64

# %%
df
# Out:
#             type                  title         director  n_directed  \
# show_id
# 1          Movie   Dick Johnson Is Dead  Kirsten Johnson           1
# 2        TV Show          Blood & Water        Not Given        2588
# 3        TV Show              Ganglands  Julien Leclercq           3
# 4        TV Show  Jailbirds New Orleans        Not Given        2588
# 5        TV Show           Kota Factory        Not Given        2588
# 6        TV Show          Midnight Mass    Mike Flanagan           4
# ...          ...                    ...              ...         ...
# 8802       Movie                Zinzana  Majid Al Ansari           1
# 8803       Movie                 Zodiac    David Fincher           6
# 8804     TV Show            Zombie Dumb        Not Given        2588
# 8805       Movie             Zombieland  Ruben Fleischer           2
# 8806       Movie                   Zoom     Peter Hewitt           1
# 8807       Movie                 Zubaan      Mozez Singh           1
#
#          director_known               country date_added  release_year rating  \
# show_id
# 1                 False         United States 2021-09-25          2020  PG-13
# 2                 False          South Africa 2021-09-24          2021  TV-MA
# 3                 False                France 2021-09-24          2021  TV-MA
# 4                 False              Pakistan 2021-09-24          2021  TV-MA
# 5                 False                 India 2021-09-24          2021  TV-MA
# 6                 False         United States 2021-09-24          2021  TV-MA
# ...                 ...                   ...        ...           ...    ...
# 8802              False  United Arab Emirates 2016-03-09          2015  TV-MA
# 8803               True         United States 2019-11-20          2007      R
# 8804              False              Pakistan 2019-07-01          2018  TV-Y7
# 8805              False         United States 2019-11-01          2009      R
# 8806              False         United States 2020-01-11          2006     PG
# 8807              False                 India 2019-03-02          2015  TV-14
#
#          show_n_seasons  movie_dur_min                             listed_in
# show_id
# 1                   NaN           90.0                           Documentary
# 2                   2.0            NaN           International,Drama,Mystery
# 3                   1.0            NaN  Crime,International,Action,Adventure
# 4                   1.0            NaN                   Documentary,Reality
# 5                   2.0            NaN         International,Romantic,Comedy
# 6                   1.0            NaN                  Drama,Horror,Mystery
# ...                 ...            ...                                   ...
# 8802                NaN           96.0          Drama,International,Thriller
# 8803                NaN          158.0                   Cult,Drama,Thriller
# 8804                2.0            NaN                    Kids,Korean,Comedy
# 8805                NaN           88.0                         Comedy,Horror
# 8806                NaN           88.0                Children,Family,Comedy
# 8807                NaN          111.0    Drama,International,Music,Musicals
#
# [8790 rows x 12 columns]

# %%
alphabet = []
alpha_count = []
for letter in string.ascii_lowercase:
    alphabet.append(letter)
    alpha_count.append(df.title.str.lower().str.contains(letter).sum())

avg = sum(alpha_count)/len(alpha_count)

plt.figure(figsize=(10, 5)) # dpi=300) # dpi=pixels per inch
plt.title('Count of letters in titles', fontdict={'fontsize': 20})
plt.xlabel('Letters', fontdict={'fontsize': 15})
plt.ylabel('Count', fontdict={'fontsize': 15})
plt.hlines(avg, xmin=-5, xmax=27, color='red', linewidth=3, linestyle='--')
plt.bar(alphabet, alpha_count)
# Out:
# <BarContainer object of 26 artists>
